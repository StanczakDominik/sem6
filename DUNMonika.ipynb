# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def Bernoulli(x, a):
    return (a*x)%1

x = np.linspace(0,1,100)
y = x
a = 2
for i in range(1):
    y = Bernoulli(y, a)

plt.plot(x, y)
plt.plot(x, a*x)


x = 0.2
y = 0.2001
xl = []
yl = []
tl = []
dl = []
for i in range(50):
    xl.append(x)
    yl.append(y)
    tl.append(i)
    dl.append(abs(y-x))
    x = Bernoulli(x, a)
    y = Bernoulli(y, a)
    

plt.plot(xl[:-1], xl[1:], 'ro-')
plt.plot(yl[:-1], yl[1:], 'co-')

# %%
plt.plot(tl, dl, 'ro-')
